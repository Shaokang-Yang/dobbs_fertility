# %%
from run_model import run_model
from clean_monthly_birth_data import subgroup_definitions
from joblib import Parallel, delayed

# Define the inputs for the function
inputs = [6, 7, 8, 9, 10, 11, 12]
outcome_type = "births" 
cats = list(subgroup_definitions[outcome_type].keys())

dists = ['NB'] # Poisson or NB
missing_flags = [True]
# disp_params = [1e-4, 1e-3]
disp_params = [1e-4]
## placebo_times = ["2020-05-01"]
placebo_times = [None]
placebo_states = [None]
sample_disp = False

args = [(dist, cat, rank, m, disp, p, tm) for dist in dists for rank in inputs for cat in cats 
        for m in missing_flags for disp in disp_params for p in placebo_states 
        for tm in placebo_times]
# Run the function in parallel
results = Parallel(n_jobs=4)(delayed(run_model)(dist=i[0], outcome_type=outcome_type, cat_name=i[1], 
                                                  rank=i[2], missingness=i[3], 
                                                  disp_param=i[4], sample_disp=sample_disp, placebo_state=i[5], 
                                                  placebo_time = i[6], results_file_suffix="sensitivity", 
                                                  num_chains=2, num_samples=1000, 
                                                  dobbs_donor_sensitivity=True,
                                                  num_warmup=500, thinning=5) for i in args)
# Out:
# ['Alabama']
# ['Alaska']
# ['Arizona']
# ['Arkansas']
# ['California']
# ['Colorado']
# ['Connecticut']
# ['Delaware']
# ['District of Columbia']
# ['Florida']
# ['Georgia']
# ['Hawaii']
# ['Idaho']
# ['Illinois']
# ['Alabama']
# ['Indiana']
# ['Alaska']
# ['Arizona']
# ['Arkansas']
# ['Alabama']
# ['California']
# ['Alaska']
# ['Colorado']
# ['Iowa']
# ['Arizona']
# ['Connecticut']
# ['Arkansas']
# ['Delaware']
# ['California']
# ['Kansas']
# ['District of Columbia']
# ['Colorado']
# ['Kentucky']
# ['Florida']
# ['Connecticut']
# ['Louisiana']
# ['Georgia']
# ['Delaware']
# ['Maine']
# ['Hawaii']
# ['District of Columbia']
# ['Maryland']
# ['Idaho']
# ['Florida']
# ['Massachusetts']
# ['Illinois']
# ['Georgia']
# ['Michigan']
# ['Alabama']
# ['Indiana']
# ['Hawaii']
# ['Iowa']
# ['Alaska']
# ['Idaho']
# ['Kansas']
# ['Arizona']
# ['Illinois']
# ['Kentucky']
# ['Minnesota']
# ['Arkansas']
# ['Indiana']
# ['Louisiana']
# ['California']
# ['Iowa']
# ['Colorado']
# ['Kansas']
# ['Mississippi']
# ['Maine']
# ['Kentucky']
# ['Missouri']
# ['Maryland']
# ['Louisiana']
# ['Montana']
# ['Massachusetts']
# ['Maine']
# ['Nebraska']
# ['Michigan']
# ['Maryland']
# ['Connecticut']
# ['Nevada']
# ['New Hampshire']
# ['Delaware']
# ['New Jersey']
# ['District of Columbia']
# ['New Mexico']
# ['Florida']
# ['New York']
# ['Massachusetts']
# ['Minnesota']
# ['Michigan']
# ['Mississippi']
# ['Georgia']
# ['North Carolina']
# ['Missouri']
# ['Hawaii']
# ['North Dakota']
# ['Montana']
# ['Idaho']
# ['Ohio']
# ['Nebraska']
# ['Minnesota']
# ['Nevada']
# ['New Hampshire']
# ['New Jersey']
# ['New Mexico']
# ['New York']
# ['Oklahoma']
# ['Mississippi']
# ['Illinois']
# ['North Carolina']
# ['Indiana']
# ['Oregon']
# ['Iowa']
# ['Missouri']
# ['Pennsylvania']
# ['Montana']
# ['Rhode Island']
# ['Kansas']
# ['South Carolina']
# ['Nebraska']
# ['North Dakota']['Kentucky']
#
# ['Nevada']
# ['South Dakota']
# ['Ohio']
# ['Tennessee']
# ['New Hampshire']
# ['Louisiana']
# ['Oklahoma']
# ['Texas']
# ['New Jersey']
# ['Maine']
# ['Oregon']
# ['Utah']
# ['New Mexico']
# ['Maryland']
# ['Pennsylvania']
# ['Vermont']
# ['Massachusetts']
# ['Rhode Island']
# ['South Carolina']
# ['South Dakota']
# ['Michigan']
# ['Minnesota']
# ['New York']
# ['Mississippi']
# ['North Carolina']
# ['North Dakota']
# ['Missouri']
# ['Ohio']
# ['Montana']
# ['Virginia']
# ['Washington']
# ['West Virginia']
# ['Tennessee']['Oklahoma']
#
# ['Wisconsin']
# ['Nebraska']
# ['Oregon']
# ['Nevada']
# ['Texas']
# ['Pennsylvania']
# ['New Hampshire']
# ['Utah']
# ['Rhode Island']
# ['Vermont']
# ['South Carolina']
# ['Virginia']
# ['South Dakota']
# ['Washington']
# ['Tennessee']
# ['West Virginia']
# ['Texas']
# ['Wisconsin']
# ['Utah']
# ['Wyoming']
# ['New Jersey']
# ['Wyoming']
# ['New Mexico']
# ['New York']
# ['Vermont']
# ['North Carolina']
# ['North Dakota']
# ['Virginia']
# ['Ohio']
# ['Washington']
# ['Oklahoma']
# ['West Virginia']
# ['Oregon']
# ['Wisconsin']
# ['Wyoming']
# ['Pennsylvania']
# ['Rhode Island']
# ['South Carolina']
# ['South Dakota']
# ['Tennessee']
# ['Texas']
# ['Utah']
# ['Vermont']
# ['Virginia']
# ['Alabama', 'Arkansas', 'Georgia', 'Idaho', 'Kentucky', 'Louisiana', 'Mississippi', 'Missouri', 'Oklahoma', 'South Dakota', 'Tennessee', 'Texas', 'West Virginia', 'Wisconsin']
# ⚠️ Warning: `dobbscode_sensitivity` column not found, skipping donor sensitivity filtering.
# ['Washington']
# ['West Virginia']
# ['Wisconsin']
# ['Alabama', 'Arkansas', 'Georgia', 'Idaho', 'Kentucky', 'Louisiana', 'Mississippi', 'Missouri', 'Oklahoma', 'South Dakota', 'Tennessee', 'Texas', 'West Virginia', 'Wisconsin']
# ⚠️ Warning: `dobbscode_sensitivity` column not found, skipping donor sensitivity filtering.
# ['Wyoming']
# ['Alabama', 'Arkansas', 'Georgia', 'Idaho', 'Kentucky', 'Louisiana', 'Mississippi', 'Missouri', 'Oklahoma', 'South Dakota', 'Tennessee', 'Texas', 'West Virginia', 'Wisconsin']
# ⚠️ Warning: `dobbscode_sensitivity` column not found, skipping donor sensitivity filtering.
# ['Alabama', 'Arkansas', 'Georgia', 'Idaho', 'Kentucky', 'Louisiana', 'Mississippi', 'Missouri', 'Oklahoma', 'South Dakota', 'Tennessee', 'Texas', 'West Virginia', 'Wisconsin']
# ⚠️ Warning: `dobbscode_sensitivity` column not found, skipping donor sensitivity filtering.
# (4, 51)
# (4, 51, 48)
# (4, 51, 48)
# (4, 51)
# (4, 51, 48)
# (4, 51, 48)
# (3, 51)
# (3, 51, 48)
# (3, 51, 48)
# (4, 51)
# (2, 51)
# (2, 51, 48)
# (2, 51, 48)
# (4, 51)
# (4, 51, 48)
# (4, 51, 48)
# (4, 51, 48)
# (4, 51, 48)
# (3, 51)
# (3, 51, 48)
# (3, 51, 48)
# (2, 51)
# (2, 51, 48)
# (2, 51, 48)
# (4, 51)
# (4, 51, 48)
# (4, 51, 48)
# (4, 51)
# (4, 51, 48)
# (4, 51, 48)
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
# (3, 51)
# (3, 51, 48)
# (3, 51, 48)
# (4, 51)
# (4, 51, 48)
# (4, 51, 48)
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
# (4, 51)
# (4, 51, 48)
# (4, 51, 48)
# (2, 51)
# (3, 51)
# (2, 51, 48)
# (2, 51, 48)
# (3, 51, 48)
# (3, 51, 48)
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Compiling.. :   0%|          | 0/1500 [00:00<?, ?it/s]
# (2, 51)
# (2, 51, 48)
# (2, 51, 48)
# (4, 51)
# (4, 51, 48)
# (4, 51, 48)
# (4, 51)
# (4, 51, 48)
# (4, 51, 48)
# (3, 51)
# (3, 51, 48)
# (3, 51, 48)
# (2, 51)
# (2, 51, 48)
# (2, 51, 48)
# Running chain 0:   0%|          | 0/1500 [00:17<?, ?it/s]
# Running chain 0:   0%|          | 0/1500 [00:18<?, ?it/s]
# Running chain 0:   0%|          | 0/1500 [00:18<?, ?it/s]
# Running chain 0:   0%|          | 0/1500 [00:19<?, ?it/s]
# Running chain 1:   0%|          | 0/1500 [00:19<?, ?it/s]
# Running chain 0:   5%|▌         | 75/1500 [01:34<24:39,  1.04s/it]
# Running chain 0:   5%|▌         | 75/1500 [01:44<26:44,  1.13s/it]
# Running chain 1:   5%|▌         | 75/1500 [01:51<29:02,  1.22s/it]
# Running chain 1:   5%|▌         | 75/1500 [01:59<32:21,  1.36s/it]
# Running chain 0:  10%|█         | 150/1500 [03:30<30:43,  1.37s/it]
# Running chain 0:  10%|█         | 150/1500 [04:28<39:27,  1.75s/it]
# Running chain 1:  10%|█         | 150/1500 [04:37<40:33,  1.80s/it]
# Running chain 1:  15%|█▌        | 225/1500 [04:42<26:32,  1.25s/it]
# Running chain 0:  15%|█▌        | 225/1500 [04:52<27:27,  1.29s/it]
